# %% [markdown]
# # Bot Visualization
#
# Import our libraries needed for the data handling.

# %%
import pandas as pd
import numpy as np
import json
import glob

# %%
#Set PANDAS to show all columns in DataFrame
pd.set_option('display.max_columns', None)
# and increase the max number of rows we can show
pd.set_option('display.max_rows', 100)

# %% [markdown]
# Libraries for stupid text encoding

# %%
from urllib2 import quote
# Unicode strings
from __future__ import unicode_literals

# %%
import feather

# %% [markdown]
# Import libraries needed for visualization.

# %%
import matplotlib.pyplot as plt
# Within notebook viewing
# %matplotlib inline

import seaborn as sns
import bokeh

# %%
# Import for axes, color, etc
from pylab import *

# %% [markdown]
# Natural Language Processing

# %%
# %run twokenize.py

# %%
# time deltas
from datetime import timedelta

# %% [markdown]
# ### Directories

# %%
testDir = '../../data/external/trump-bots/'
botDir = '../../data/external/botresults/'
outDir = '../../data/processed/bot-tweets/'

# %% [markdown]
# Read in the data files by combining the extracted files.

# %%
# Crudely combine
process = []
for f in glob.glob((botDir + "*.txt")):
    with open(f, "rb") as infile:
        for line in infile:
            process.append(json.loads(line))
raw = pd.DataFrame.from_records(process)

del process

print (raw.shape)
# Out:
# (77722, 33)

# %%
feather.write_dataframe(raw, 'raw.feather')
# Out:
# ---------------------------------------------------------------------------
# FeatherError                              Traceback (most recent call last)
# <ipython-input-11-cbc4c91f8f6d> in <module>()
# ----> 1 feather.write_dataframe(raw, 'raw.feather')
#
# /home/user/.anaconda3/envs/py27/lib/python2.7/site-packages/feather/api.pyc in write_dataframe(df, path)
#      59             name = str(name)
#      60
# ---> 61         writer.write_array(name, col)
#      62
#      63     writer.close()
#
# /home/user/.anaconda3/envs/py27/lib/python2.7/site-packages/feather/ext.pyx in feather.ext.FeatherWriter.write_array (feather/ext.cpp:2731)()
#      97             self.write_timestamp(name, col, mask)
#      98         else:
# ---> 99             self.write_primitive(name, col, mask)
#     100
#     101     cdef write_category(self, name, col, mask):
#
# /home/user/.anaconda3/envs/py27/lib/python2.7/site-packages/feather/ext.pyx in feather.ext.FeatherWriter.write_primitive (feather/ext.cpp:3100)()
#     120
#     121         col_values = _unbox_series(col)
# --> 122         self.write_ndarray(col_values, mask, &values)
#     123         check_status(self.writer.get().AppendPlain(c_name, values))
#     124
#
# /home/user/.anaconda3/envs/py27/lib/python2.7/site-packages/feather/ext.pyx in feather.ext.FeatherWriter.write_ndarray (feather/ext.cpp:3453)()
#     147     cdef int write_ndarray(self, values, mask, PrimitiveArray* out) except -1:
#     148         if mask is None:
# --> 149             check_status(pandas_to_primitive(values, out))
#     150         else:
#     151             check_status(pandas_masked_to_primitive(values, mask, out))
#
# /home/user/.anaconda3/envs/py27/lib/python2.7/site-packages/feather/ext.pyx in feather.ext.check_status (feather/ext.cpp:1913)()
#      55
#      56     cdef string c_message = status.ToString()
# ---> 57     raise FeatherError(frombytes(c_message))
#      58
#      59 cdef update_mask_with_datatype_nulls(mask, values):
#
# FeatherError: Invalid: Unable to infer type of object array, were all null

# %% [markdown]
# ##### Helper functions

# %%
def tknz(text):
    tokens = tokenizeRawTweetText(text)
    filt = [x for x in tokens if not (x.startswith('RT') 
                                   or x.startswith('@') or x.startswith(':') 
                                   or x.startswith('http://') or x.startswith('https://') 
                                  or x.startswith('-') or x.startswith('and') 
                                    or x.startswith('.') or x.startswith(',') 
                                    or x.startswith('?') 
                                     or x.startswith("'") or x == ('' or '"' or 'a'))]
    return filt

def hsh(tokens):
    # reads a list of tokens
    # tuped = tuple(tokens)
    tuped = ', '.join(tokens)
    hashed = hash(tuped)
    return hashed

# formatting for the datetime display
def timeDeltaDisplay(td):
    if (td.total_seconds() // 86400) < 1:
        return ('{} hours'.format((td.total_seconds() // 3600)))
    else:
        return ('{} days'.format(td.days))
    
def extractInfo(tweet):
    # User variables
    userID = tweet['user']['id_str']
    screenName = tweet['user']['screen_name']
    # Tweet Variables
    text = tweet['text']
    tokens = tknz(text)
    hashed = hsh(tokens)
    retweet = 1 if (type(tweet['retweeted_status']) == dict) else 0
    retweet_count = tweet['retweet_count']
    favorite_count = tweet['favorite_count']
    
    timestamp = tweet['timestamp_ms']
    
    return {'userID':userID, 'screenName':screenName, 'timestamp':timestamp, \
            'text':text, 'tokens':tokens, 'hash':hashed, 'retweet':retweet, \
           'retweet_count': retweet_count, 'favorite_count':favorite_count}

# %%
extracted = pd.DataFrame.from_records(raw.apply(lambda x: extractInfo(x), axis=1))

# %%
# throw out the tweets we can't classify
extracted = extracted[extracted['hash'] != 0]

# Calc variables
extracted['timestamp'] = pd.to_datetime(extracted['timestamp'], unit='ms')
extracted['token_str'] = extracted['tokens'].apply(lambda x: ', '.join(x))

extracted.head()
# Out:
#    favorite_count                 hash  retweet  retweet_count  \
# 0               0  8401775961062800512        1              0
# 1               0 -7017692310915600254        1              0
# 2               0  4819910249842125834        1              0
# 3               0  8041086589735528761        0              0
# 4               0 -4371809372265221000        1              0
#
#        screenName                                               text  \
# 0       Scrufey21  RT @robinleeclark: Hillary is a murderer and a...
# 1       Scrufey21  RT @PatriotMash: Clinton uses two aides and a ...
# 2       Scrufey21  RT @NoahWehrman: Press prepare for another day...
# 3  CyberAnonymous  nytimes: Hillary Clinton reassures gay youth i...
# 4       Scrufey21  RT @LessGovMoreFun: Truth be told:  https://t....
#
#                 timestamp                                             tokens  \
# 0 2015-07-06 00:12:43.046  [Hillary, is, a, murderer, a, traitor, that's,...
# 1 2015-07-06 00:17:23.293  [Clinton, uses, two, aides, a, rope, to, lasso...
# 2 2015-07-06 00:19:58.259  [Press, prepare, for, another, day, of, coveri...
# 3 2015-07-06 00:20:15.542  [nytimes, Hillary, Clinton, reassures, gay, yo...
# 4 2015-07-06 00:20:17.984                                  [Truth, be, told]
#
#       userID                                          token_str
# 0  490179072  Hillary, is, a, murderer, a, traitor, that's, ...
# 1  490179072  Clinton, uses, two, aides, a, rope, to, lasso,...
# 2  490179072  Press, prepare, for, another, day, of, coverin...
# 3  128334973  nytimes, Hillary, Clinton, reassures, gay, you...
# 4  490179072                                    Truth, be, told

# %%
agg = {
    'userID': {
        'uniq_users': pd.Series.nunique,
        'users': pd.Series.tolist
    }, 'timestamp': {
        'first_day': 'min',
        'last_day': 'max',
        # Calculate time delta # # ).days if (max(x)-min(x).hours > 24) else (max(x)-min(x)).hours
        'time_delta': lambda x: max(x)-min(x)
    }, 
    'hash': 'count',
    'favorite_count': {
        'total_favorites': 'sum',
        'avg_favorites': 'mean'
    },
    'retweet_count': {
        'total_retweets': 'sum',
        'avg_retweets': 'mean'
    }
}

aggregated = extracted.groupby(['token_str']).agg(agg)

# %%
# reset the index so it's easier to work with
aggregated.reset_index(col_level=1, inplace=True, drop=False)
aggregated.columns = ['token_str', 'first_day', 'time_delta', 'last_day', 'avg_retweets', 'total_retweets', 'uniq_users', 'users', \
                      'total_favorites', 'avg_favorites', 'count']    

# Turn the list into a set
aggregated['users'] = aggregated['users'].apply(lambda x: set(x))

aggregated.sort_values('count', inplace=True, ascending=False)
aggregated.head(1)
# Out:
#                                                token_str  \
# 23714  Donald, Trump, was, just, mentioned, during, E...
#
#                     first_day               time_delta  \
# 23714 2015-10-15 01:18:02.734 121 days 22:38:49.538000
#
#                      last_day  avg_retweets  total_retweets  uniq_users  \
# 23714 2016-02-13 23:56:52.272             0               0           1
#
#               users  total_favorites  avg_favorites  count
# 23714  {3920277023}                0              0   1574

# %% [markdown]
# ---
#
# Now that we have our aggregated list of duplicate tweets, let's make a couple of `.csv`'s so that we can render `D3.js` timeline plots.
#
# First we'll make a simple Gantt chart with the first and last Bot-Tweet appearance.

# %%
# write gantt chart to csv, use unicode formatting or else we'll get errors
gantt = 'gantt.csv'
#aggregated[['token_str', 'uniq_users', 'count', 'first_day', 'last_day', 'time_delta']].iloc[0:49].to_csv(gantt, index=False, encoding='utf-8')

# %%
worstOffenders = aggregated['token_str'].iloc[0:9].tolist()
# snippet to turn the groupby to a dict whose keys are group labels and vals are DF's
groupedTokens = extracted.groupby('token_str')

# %%
# iter through list and create a DF by concatenating groups
frames = []
for i in worstOffenders:
    frames.append(groupedTokens.get_group(i))
result = pd.concat(frames)

result.to_csv('top-10-bot-tweets.csv', index=False, encoding='utf-8')

# %%
aggregated[['token_str', 'time_delta', 'uniq_users', 'count']]\
    .sort_values('time_delta', ascending=false)\
    .head(25).style.format(timeDeltaDisplay, subset=['time_delta'])\
    .bar(subset=['count', 'total_favorites', 'total_retweets', 'time_delta', 'uniq_users'], color='#d65f5f')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-315a865ba865> in <module>()
# ----> 1 aggregated[['token_str', 'time_delta', 'uniq_users', 'count']]    .sort_values('time_delta', ascending=false)    .head(25).style.format(timeDeltaDisplay, subset=['time_delta'])    .bar(subset=['count', 'total_favorites', 'total_retweets', 'time_delta', 'uniq_users'], color='#d65f5f')
#
# NameError: name 'aggregated' is not defined

# %% [markdown]
# We've noticed some very interesting patterns! Several to note...
#
# 1. The time duration of a Bot's 'template' varies significantly! Thomas et Al. found that the majority of their bots had account durations less than 1 month (77% ?). These results indicate that while some campaigns are done in short bursts, an impactful portion of the bots (those who are producing the most tweets) stick around longer. Difference is because?
# 2. Templates, repitition in tweets. `@DonaldTrumpTVFan` is the the user with the most volume by far. It appears that he uses a template to distribute Trump appearances on TV.
# 3. User's. # unique users, etc.

# %%
# 2. Getting rid of @dnaldtrumptvfan we can look at tweets from users that arent him
# # Top tweets filtered
aggregated[aggregated['users'] != set([u'3920277023'])][['token_str', 'time_delta', 'uniq_users', 'count']].head(25)\
    .style.format(timeDeltaDisplay, subset=['time_delta'])\
    .bar(subset=['count', 'total_favorites', 'total_retweets', 'time_delta', 'uniq_users'], color='#d65f5f')
# Out:
#         <style  type="text/css" >
#
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row0_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 18.9043232121%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row0_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 2.04081632653%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row0_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row1_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 37.2602490713%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row1_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 2.04081632653%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row1_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 57.5363427697%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row2_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 56.7735641003%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row2_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row2_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 6.96250956389%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row3_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 1.0635220934%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row3_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row3_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 5.20275439939%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row4_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.441394246901%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row4_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row4_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 3.67253251721%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row5_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 56.3607517464%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row5_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row5_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 3.36648814078%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row6_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.522641730814%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row6_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row6_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 2.83091048202%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row7_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 54.6882226245%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row7_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 95.9183673469%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row7_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 2.52486610559%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row8_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.0622648613026%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row8_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row8_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 2.06579954093%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row9_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.514612935955%, transparent 0%);
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211row9_col2 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#             }
#
#             #T_7f752a08_bd92_11e6_970b_3d4f98da5211ro

# %%
# 3.
# # Look at Bot Tweet's with more than one uniq user.
# # Are there any tweets that come in bursts from a diverse group of users? <-- YES
# # # Filter out those tweets that dont have multiple users AND who all came within the same timeframe
aggregated[(aggregated['uniq_users'] > 1) & (aggregated['time_delta'] < timedelta(hours=10))][['token_str', 'time_delta', 'users', 'uniq_users', 'count']].head(25).sort_values('uniq_users', ascending=False)\
    .style.format(timeDeltaDisplay, subset=['time_delta'])\
    .bar(subset=['count', 'total_favorites', 'total_retweets', 'time_delta', 'uniq_users'], color='#d65f5f')
# Out:
#         <style  type="text/css" >
#
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row0_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 65.5732405319%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row0_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row0_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 42.1052631579%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row1_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 42.2563962115%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row1_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row1_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 36.8421052632%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row2_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.0701964064224%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row2_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 94.1176470588%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row2_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 31.5789473684%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row3_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 18.0664753657%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row3_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 94.1176470588%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row3_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 31.5789473684%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row4_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.0975673573222%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row4_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 94.1176470588%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row4_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 31.5789473684%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row5_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.0131423087462%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row5_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 94.1176470588%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row5_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 31.5789473684%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row6_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.172883151454%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row6_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 94.1176470588%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row6_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 31.5789473684%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row7_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.125353573286%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row7_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 94.1176470588%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row7_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 31.5789473684%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row8_col1 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 0.0343241491319%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row8_col3 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 94.1176470588%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row8_col4 {
#
#                 width:  10em;
#
#                  height:  80%;
#
#                 background:  linear-gradient(90deg,#d65f5f 31.5789473684%, transparent 0%);
#
#             }
#
#             #T_679bae68_bd95_11e6_970b_3d4f98da5211row9_col1 {
#
#                 widt

# %%
collusion = extracted[extracted['userID'].isin(set([u'1214297077', u'1214302297', u'372028801', u'1214307817', 
                                      u'1214310979', u'1214290435', u'1214286984', u'1214293885', 
                                      u'1214308945', u'1214286679', u'1214267976', u'1214306713', 
                                      u'490179072', u'1214284272', u'1214278321', u'1214281278', 
                                      u'1214288034', u'1214285328', u'1214299358']))]
# Double check
collusion['userID'].unique()

# %%
collusion.to_csv((outDir + 'collusion-network.csv'), index=False, encoding='utf-8')
